# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.common.by import By
import time

# %%
#Q1.
driver = webdriver.Chrome(r"C:\Users\User\Downloads\Fliprobo\chromedriver.exe")
driver.get("https://www.naukri.com/")

# %%
designation = driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys('Data Scientist')

search1=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search1.click()

# %%
loc= driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[5]/div[2]/div[2]/label/i")
loc.click()

# %%
salary= driver.find_element(By.XPATH,"/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]")
salary.click()

# %%
job_title2=[]
job_location2=[]
company_name2=[]
experience_required2=[]

# %%
title_tags2=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags2[0:10]:
    title=i.text
    job_title2.append(title)

location_tags2=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags2[0:10]:
    location=i.text
    job_location2.append(location)
    
company_tags2=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags2[0:10]:
    company=i.text
    company_name2.append(company)

experience_tags2=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in experience_tags2[0:10]:
    exp=i.text
    experience_required2.append(exp)

# %%
#creating DataFrame 

df2= pd.DataFrame({"Job Title":job_title2,"Job Location":job_location2,"Company Name":company_name2,"Experience Required":experience_required2})
df2
# Out:
#                                            Job Title  \
# 0  Artificial Intelligence/Computer Vision Engine...
# 1          Data Activation Specialist - Adobe Target
# 2                                     Data Scientist
# 3                  Data Scientist - Engine Algorithm
# 4  Opening For Jr. Data Scientist with Tatras Dat...
# 5                                     Data Scientist
# 6                                     Data Scientist
# 7  URGENT: Data Scientist | Gurugram | 5 Days Wor...
# 8                                     Data Scientist
# 9                              SE/SSE-Data Scientist
#
#                                         Job Location  \
# 0  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 1  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 2                                  Temp. WFH - Noida
# 3  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 4                                        Delhi / NCR
# 5  Dehradun, Hyderabad/Secunderabad, Gurgaon/Guru...
# 6                                   Gurgaon/Gurugram
# 7                                   Gurgaon/Gurugram
# 8                                              Noida
# 9                                        Delhi / NCR
#
#                     Company Name Experience Required
# 0                         Vicara             1-3 Yrs
# 1                 Okda Solutions            7-10 Yrs
# 2                   NGI Ventures             1-5 Yrs
# 3                   Primo Hiring             1-3 Yrs
# 4           Tatras Data Services             2-4 Yrs
# 5           torcai digital media             2-7 Yrs
# 6  Americana Restaurants (india)             3-8 Yrs
# 7                     Digilytics             2-5 Yrs
# 8    Alliance Recruitment Agency             3-4 Yrs
# 9        Bold Technology Systems             3-8 Yrs

# %%
#Q2.
driver = webdriver.Chrome(r"C:\Users\User\Downloads\Fliprobo\chromedriver.exe")
driver.get("https://www.naukri.com/")

# %%
designation = driver.find_element(By.CLASS_NAME,"suggestor-input ")
designation.send_keys('Data Scientist')

# %%
location1 = driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
location1.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title1=[]
job_location1=[]
company_name1=[]

# %%
title_tags1=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tags1[0:10]:
    title=i.text
    job_title1.append(title)

location_tags1=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tags1[0:10]:
    location=i.text
    job_location1.append(location)
    
company_tags1=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tags1[0:10]:
    company=i.text
    company_name1.append(company)

# %%
#creating DataFrame 
df1= pd.DataFrame({"Job Title":job_title1,"Job Location":job_location1,"Company Name":company_name1})
df1
# Out:
#                                            Job Title  \
# 0                   Analystics & Modeling Specialist
# 1                                     Data Scientist
# 2                                     Data Scientist
# 3                               Manager-Data Science
# 4                                     Data Scientist
# 5                                Data Scientist - II
# 6                              Senior Data Scientist
# 7   ACN - Applied Intelligence - Data Scientist - 09
# 8  Python Programming Language Data Science Pract...
# 9  ACN - Applied Intelligence - C4DI - Sustainabi...
#
#                                         Job Location      Company Name
# 0  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...         Accenture
# 1  Bangalore/Bengaluru, New Delhi, Hyderabad/Secu...       Tata Nexarc
# 2                  Bangalore/Bengaluru, Nagpur, Pune     Tech Mahindra
# 3                                Bangalore/Bengaluru  AMERICAN EXPRESS
# 4  Hybrid - Bangalore/Bengaluru, Noida, Kolkata, ...          Mindtree
# 5     Bangalore/Bengaluru, India, Mumbai (All Areas)           Bizongo
# 6                        Bangalore/Bengaluru, Mumbai      Baker Hughes
# 7                                Bangalore/Bengaluru         Accenture
# 8                                Bangalore/Bengaluru         Accenture
# 9                                Bangalore/Bengaluru         Accenture

# %%
#Q3.
driver = webdriver.Chrome(r"C:\Users\User\Downloads\Fliprobo\chromedriver.exe")
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market")

# %%
rating=[]
summary=[]
review=[]

# %%
start=0
end=10
for page in range(start,end):
    rate= driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in rate[0:100]:
        rating.append(i.text)
        
for page in range(start,end):
    sum= driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for d in sum[0:100]:
        summary.append(d.text)
        
for page in range(start,end):
    rev= driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for d in rev[0:100]:
        review.append(d.text)
        
        
    next_button1= driver.find_element(By.XPATH,'//a[@class="_1LKTO3" and span="Next"]')
    next_button1.click()
    time.sleep(3)

# %%
#creating DataFrame 

df4= pd.DataFrame({"Rating":rating[0:100],"Review Summary":summary[0:100],"Full Review":review[0:100]})
df4
# Out:
#    Rating       Review Summary  \
# 0       5       Simply awesome
# 1       5     Perfect product!
# 2       5  Best in the market!
# 3       4      Value-for-money
# 4       5    Worth every penny
# ..    ...                  ...
# 95      5   Highly recommended
# 96      5   Highly recommended
# 97      5     Perfect product!
# 98      4          Pretty good
# 99      5        Great product
#
#                                           Full Review
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   I'm Really happy with the product\nDelivery wa...
# 4   Previously I was using one plus 3t it was a gr...
# ..                                                ...
# 95  A perfect phone and a good battery super camer...
# 96  Excellent camera 📸 And Display touching very N...
# 97  🤩🤩🤩🤩🤩🤩I loved the Phone.. Every time I pick up...
# 98  Excellent camera and display touching very nic...
# 99  I got this beast today. And I must say the pic...
#
# [100 rows x 3 columns]

# %%
#Q4.
driver = webdriver.Chrome(r"C:\Users\User\Downloads\Fliprobo\chromedriver.exe")
driver.get("https://www.flipkart.com/")

# %%
shoes= driver.find_element(By.CLASS_NAME,"_3704LK")
shoes.send_keys('Sneakers')

search6=driver.find_element(By.CLASS_NAME,"_34RNph")
search6.click()

# %%
sneak_brand=[]
sneak_desc=[]
sneak_price=[]

# %%
start=0
end=3
for page in range(start,end):
    brand= driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in brand:
        sneak_brand.append(i.text)
        
for page in range(start,end):
    descr= driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for d in descr:
        sneak_desc.append(d.text)
        
for page in range(start,end):
    price= driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for d in price:
        sneak_price.append(d.text)
        
        
    next_button2= driver.find_element(By.XPATH,'//a[@class="_1LKTO3" and span="Next"]')
    next_button2.click()
    time.sleep(3)

# %%
#creating DataFrame 

df6= pd.DataFrame({"Brand":sneak_brand[0:100],"Product Description":sneak_desc[0:100],"Price":sneak_price[0:100]})
df6
# Out:
#                       Brand  \
# 0                  HOTSTYLE
# 1                        TR
# 2                    Labbin
# 3                    Shozie
# 4                       SFR
# ..                      ...
# 95                   Footox
# 96  Bond Street By Red Tape
# 97                Deals4you
# 98                   Kraasa
# 99                  edisson
#
#                                   Product Description   Price
# 0                               CR-1 Sneakers For Men    ₹449
# 1   Running / Walking / Sport Shoes For Men Sneake...    ₹494
# 2                                    Sneakers For Men    ₹399
# 3                                    Sneakers For Men    ₹295
# 4   PLANCK Smart Grey Lace-Ups Casuals Sneakers Sn...    ₹209
# ..                                                ...     ...
# 95           WATERPROOF-05cFULLWHITE Sneakers For Men    ₹842
# 96  PLANCK Smart Red Lace-Ups Casuals Sneakers Sne...    ₹229
# 97                                   Sneakers For Men    ₹549
# 98                                   Sneakers For Men  ₹1,299
# 99                                   Sneakers For Men  ₹1,799
#
# [100 rows x 3 columns]

# %%
#Q5.
driver = webdriver.Chrome(r"C:\Users\User\Downloads\Fliprobo\chromedriver.exe")
driver.get("https://www.amazon.in/")

# %%
item = driver.find_element(By.ID,"twotabsearchtextbox")
item.send_keys('Laptop')

search=driver.find_element(By.CLASS_NAME,"nav-right")
search.click()

# %%
core= driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[6]/li[12]/span/a/div")
core.click()

# %%
title=[]
rating=[]
price=[]

# %%
name= driver.find_elements(By.XPATH,'//h2[@class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"]')
for i in name[0:10]:
    titlen=i.text
    title.append(titlen)
    
rate=driver.find_elements(By.XPATH,'//span[@class="a-size-base"]')
for i in rate[0:10]:
    star=i.text
    rating.append(star)
    
cash=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in cash[0:10]:
    cas=i.text
    price.append(cas)

# %%
#creating DataFrame 

df = pd.DataFrame({"Title":title,"Rating":rating,"Price":price})
df
# Out:
#                                                Title Rating     Price
# 0  Acer Predator Helios 300 Gaming Laptop Intel C...    3.9  1,15,990
# 1  ASUS Zenbook Pro 14 Duo OLED (2022) Dual Scree...    5.0  2,14,990
# 2  Acer Predator Helios 500 Gaming Laptop (11Th G...    4.7  4,32,435
# 3  Dell G15-5521 Gaming Laptop, i9-12900H, 16GB D...    3.9  1,81,833
# 4  Acer Predator Helios 300 Gaming Laptop Intel C...    4.7  1,49,990
# 5  Acer Predator Helios 300 Gaming Laptop Intel C...    1.0  1,89,990
# 6  ASUS ROG Strix Scar 15 (2022), Intel Core i9-1...    5.0  3,12,990
# 7  ASUS ROG Strix Scar 15 (2022), 15.6" (39.62 cm...    5.0  3,01,980
# 8  ASUS ProArt Studiobook 16 OLED (2022) Dial, 16...    3.1  2,57,966
# 9  HP Omen 12th Gen Intel Core i9-12900HX 17.3 in...    3.7  3,39,500

# %%
#Q6.
driver = webdriver.Chrome(r"C:\Users\User\Downloads\Fliprobo\chromedriver.exe")
driver.get("https://www.azquotes.com/")

# %%
search7=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a")
search7.click()

# %%
quote=[]
aut=[]
toq=[]

# %%
start=0
end=10
for page in range(start,end):
    qut= driver.find_elements(By.XPATH,'//a[@class="title"]')
    for i in qut:
        quote.append(i.text)
        
for page in range(start,end):
    auth= driver.find_elements(By.XPATH,'//div[@class="author"]')
    for d in auth:
        aut.append(d.text)
        
for page in range(start,end):
    type= driver.find_elements(By.XPATH,'//div[@class="tags"]')
    for d in type:
        toq.append(d.text)
        
        
    next_button3= driver.find_element(By.XPATH,"/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[3]/li[12]/a")
    next_button3.click()
    time.sleep(3)

# %%
#creating DataFrame 

df8= pd.DataFrame({"Quote":quote[0:1000],"Author":aut[0:1000],"Type Of Quote":toq[0:1000]})
df8
# Out:
#                                                  Quote                Author  \
# 0    The essence of strategy is choosing what not t...        Michael Porter
# 1    One cannot and must not try to erase the past ...            Golda Meir
# 2    Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...        Nelson Mandela
# 4    You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                 ...                   ...
# 995     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 996  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 997  If you think you are too small to make a diffe...            Dalai Lama
# 998  God doesn't require us to succeed, he only req...         Mother Teresa
# 999    Change your thoughts and you change your world.  Norman Vincent Peale
#
#                                 Type Of Quote
# 0    Essence, Deep Thought, Transcendentalism
# 1                   Inspiration, Past, Trying
# 2                         Country, Peace, War
# 3          Inspirational, Motivational, Death
# 4                4th Of July, Food, Patriotic
# ..                                        ...
# 995         Love, Inspirational, Motivational
# 996                    Gun, Two, Qualms About
# 997     Inspirational, Greatness, Best Effort
# 998                    Spiritual, Truth, Yoga
# 999      Inspirational, Leadership, Education
#
# [1000 rows x 3 columns]

# %%
#Q7
driver = webdriver.Chrome(r"C:\Users\User\Downloads\Fliprobo\chromedriver.exe")
driver.get("https://www.jagranjosh.com/")

# %%
gk=driver.find_element(By.XPATH,"/html/body/div/div[1]/div/div[1]/div/div[6]/div/div[1]/header/div[3]/ul/li[9]/a")
gk.click()

# %%
pm=driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a")
pm.click()

# %%
name=[]
bod=[]
office=[]
remarks=[]

# %%
pm_list=driver.find_elements(By.TAG_NAME,"tr")
for i in pm_list[1:19]:
    name.append(i.text.split("\n")[1])
    bod.append(i.text.split("\n")[2])
    office.append(i.text.split("\n")[3])
for i in list_tags[1:18]:    
    remarks.append(i.text.split("\n")[5])

remarks.append(driver.find_element(By.XPATH, '/html/body/div[1]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/span/div[2]/table/tbody/tr[19]/td[5]/p').text)

# %%
#creating DataFrame 

df9=pd.DataFrame({"Name":name,"Born-Dead":bod,"Term of Office":office,"Remarks":remarks})
df9
# Out:
#                            Name     Born-Dead  \
# 0             Jawahar Lal Nehru   (1889–1964)
# 1     Gulzarilal Nanda (Acting)   (1898-1998)
# 2           Lal Bahadur Shastri   (1904–1966)
# 3   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 4                 Indira Gandhi   (1917–1984)
# 5                 Morarji Desai   (1896–1995)
# 6                  Charan Singh   (1902–1987)
# 7                 Indira Gandhi   (1917–1984)
# 8                  Rajiv Gandhi   (1944–1991)
# 9                   V. P. Singh   (1931–2008)
# 10              Chandra Shekhar   (1927–2007)
# 11          P. V. Narasimha Rao   (1921–2004)
# 12         Atal Bihari Vajpayee  (1924- 2018)
# 13             H. D. Deve Gowda   (born 1933)
# 14           Inder Kumar Gujral   (1919–2012)
# 15         Atal Bihari Vajpayee   (1924-2018)
# 16               Manmohan Singh   (born 1932)
# 17                Narendra Modi   (born 1950)
#
#                          Term of Office  \
# 0         15 August 1947 to 27 May 1964
# 1           27 May 1964 to 9 June 1964,
# 2        9 June 1964 to 11 January 1966
# 3    11 January 1966 to 24 January 1966
# 4      24 January 1966 to 24 March 1977
# 5       24 March 1977 to  28 July 1979
# 6       28 July 1979 to 14 January 1980
# 7    14 January 1980 to 31 October 1984
# 8    31 October 1984 to 2 December 1989
# 9   2 December 1989 to 10 November 1990
# 10     10 November 1990 to 21 June 1991
# 11          21 June 1991 to 16 May 1996
# 12           16 May 1996 to 1 June 1996
# 13         1 June 1996 to 21 April 1997
# 14      21 April 1997 to 19 March 1998
# 15        19 March 1998 to 22 May 2004
# 16        22 May 2004 to 26 May 2014
# 17                26 May 2014 - Present
#
#                                               Remarks
# 0   The first prime minister of India and the long...
# 1                            First acting PM of India
# 2   He has given the slogan of 'Jai Jawan Jai Kisa...
# 3                                                   -
# 4                First female Prime Minister of India
# 5   Oldest to become PM (81 years old) and first t...
# 6             Only PM who did not face the Parliament
# 7   The first lady who served as PM for the second...
# 8                Youngest to become PM (40 years old)
# 9   First PM to step down after a vote of no confi...
# 10              He belongs to  Samajwadi Janata Party
# 11                          First PM from south India
# 12                             PM for shortest tenure
# 13                          He belongs to  Janata Dal
# 14                                             ------
# 15   The first non-congress PM who completed a ful...
# 16                                      First Sikh PM
# 17  4th Prime Minister of India who served two con...

# %%
#Q8.
driver = webdriver.Chrome(r"C:\Users\User\Downloads\Fliprobo\chromedriver.exe")
driver.get("https://www.motor1.com/")

# %%
drop=driver.find_element(By.CLASS_NAME,"m1-hamburger-button")
drop.click()

# %%
feat= driver.find_element(By.XPATH,"/html/body/div[4]/div[1]/div[3]/ul/li[5]/a")
feat.click()

# %%
cars=driver.find_element(By.XPATH,"/html/body/div[3]/div[8]/div/div[1]/div[1]/div[2]/div/div[1]/h3/a")
cars.click()

# %%
car_name=[]
car_desc=[]
car_price=[]

# %%
carn= driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in carn:
    car_name.append(i.text)
    
card=driver.find_elements(By.TAG_NAME,"p")
for i in card:
    car_desc.append(i.text.replace("Price",""))
    
carp=driver.find_elements(By.TAG_NAME,"strong")
for i in carp:
    car_price.append(i.text)

# %%
#creating DataFrame 

df10=pd.DataFrame({"Car Name":car_name[0:50],"Description":car_desc[4:54],"Car Price":car_price[0:50]})
df10
# Out:
#                            Car Name  \
# 0                         Drako GTE
# 1                     De Tomaso P72
# 2                 Ferrari LaFerrari
# 3                     Pagani Huayra
# 4                      McLaren Elva
# 5                       Czinger 21C
# 6                     Ferrari Monza
# 7                Gordon Murray T.33
# 8                 Koenigsegg Gemera
# 9                       Zenvo TSR-S
# 10               Hennessey Venom F5
# 11                  Bentley Bacalar
# 12    Hispano Suiza Carmen Boulogne
# 13           Bentley Mulliner Batur
# 14                     Deus Vayanne
# 15                      SSC Tuatara
# 16                      Lotus Evija
# 17              Aston Martin Vulcan
# 18                       Delage D12
# 19                McLaren Speedtail
# 20                     Rimac Nevera
# 21                    Pagani Utopia
# 22             Pininfarina Battista
# 23                Ferrari FXX K Evo
# 24               Gordon Murray T.50
# 25             Lamborghini Countach
# 26         Mercedes-AMG Project One
# 27              Aston Martin Victor
# 28      Hennessey Venom F5 Roadster
# 29                 Koenigsegg Jesko
# 30            Aston Martin Valkyrie
# 31        W Motors Lykan Hypersport
# 32                    McLaren Solus
# 33        Pagani Huayra Roadster BC
# 34         Bugatti Chiron Pur Sport
# 35                 Lamborghini Sian
# 36                 Koenigsegg CC850
# 37  Bugatti Chiron Super Sport 300+
# 38               Lamborghini Veneno
# 39                   Bugatti Bolide
# 40                  Bugatti Mistral
# 41              Pagani Huayra Imola
# 42                     Bugatti Divo
# 43              SP Automotive Chaos
# 44                 Pagani Codalunga
# 45         Mercedes-Maybach Exelero
# 46               Bugatti Centodieci
# 47             Rolls-Royce Sweptail
# 48         Bugatti La Voiture Noire
# 49           Rolls-Royce Boat Tail*
#
#                                           Description             Car Price
# 0                                 Price: $1.2 Million   Price: $1.2 Million
# 1   The Drako GTE is a super sedan in every sense ...   Price: $1.3 Million
# 2                                 Price: $1.3 Million   Price: $1.4 Million
# 3   The De Tomaso P72 is basically the definition ...   Price: $1.4 Million
# 4                                 Price: $1.4 Million
# 5   At $1.4 million new, the Ferrari LaFerrari is ...   Price: $1.7 Million
# 6                                 Price: $1.4 Million   Price: $1.7 Million
# 7   Inarguably one of the prettiest cars on this l...   Price: $1.7 Million
# 8                                 Price: $1.7 Million   Price: $1.7 Million
# 9   The McLaren Elva is one of the latest addition...   Price: $1.7 Million
# 10                                Price: $1.7 Million   Price: $1.7 Million
# 11  You might not know the name Czinger yet, but t...   Price: $1.8 Million
# 12                                Price: $1.7 Million   Price: $1.9 Million
# 13  Much like the roof-less McLaren Elva, the Ferr...   Price: $1.9 Million
# 14                                Price: $1.7 Million   Price: $2.0 Million
# 15  The second and slightly more affordable superc...   Price: $2.0 Million
# 16                                Price: $1.7 Million  Price: $2.0 Million*
# 17  One of two Koenigsegg models on this list, the...   Price: $2.1 Million
# 18                                Price: $1.7 Million   Price: $2.3 Million
# 19  Hailing from Denmark, the Zenvo TSR-S debuted ...   Price: $2.3 Million
# 20                                Price: $1.8 Million   Price: $2.3 Million
# 21  The Hennessey Venom GT was a record-breaker, t...   Price: $2.4 Million
# 22                                Price: $1.9 Million   Price: $2.5 Million
# 23  With just 12 total units produced, the Bentley...   Price: $2.5 Million
# 24                                Price: $1.9 Million   Price: $2.6 Million
# 25  To call the Hispano Suiza Carmen Boulogne beau...   Price: $2.6 Million
# 26                                Price: $2.0 Million   Price: $2.6 Million
# 27  The electric onslaught is coming. Bentley says...   Price: $2.7 Million
# 28                                Price: $2.0 Million   Price: $3.0 Million
# 29  The Deus Vayanne may not be a household name (...          $3.0 Million
# 30                               Price: $2.0 Million*   Price: $3.0 Million
# 31  Although initially cloaked in controversy, SSC...   Price: $3.2 Million
# 32                                Price: $2.1 Million   Price: $3.4 Million
# 33  With a new Emira sports car and an Eletre elec...          $3.5 Million
# 34                                Price: $2.3 Million   Price: $3.5 Million
# 35  As with a few other cars on this list, the Ast...   Price: $3.6 Million
# 36                                Price: $2.3 Million   Price: $3.6 million
# 37  You may have heard of Delage before. In the ea...   Price: $3.7 Million
# 38                                Price: $2.3 Million   Price: $3.9 Million
# 39  What would you pay for the fastest production ...   Price: $4.5 Million
# 40                                Price: $2.4 Million   Price: $4.7 Million
# 41  The Rimac Nevera takes the title of most expen...   Price: $5.0 Million
# 42                                Price: $2.5 Million   Price: $5.4 Million
# 43  First came the Zonda, then the Huayra, and now...   Price: $5.8 Million
# 44                                Price: $2.5 Million   Price: $6.4 Million
# 45  Aptly named after the company’s founder, Batti...   Price: $7.4 Million
# 46                                Price: $2.6 Million   Price: $8.0 Million
# 47  Sure, you could buy a normal LaFerrari (which ...   Price: $9.0 Million
# 48                                Price: $2.6 Million  Price: $12.8 Million
# 49  If the name Gordon Murray sounds familiar, it’...  Price: $13.4 Million
